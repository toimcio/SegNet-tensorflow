# %%
from SegNet import SegNet

# %% [markdown]
# ## Train dataset

# %%
SegNet().visual_results("TRAIN", 2)
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./saved_models/segnet_vgg_bayes/segnet_vgg_bayes_30000/model.ckpt-30000
# 367 CamVid test images are loaded

# %% [markdown]
# ## Validation dataset

# %%
SegNet().visual_results("VAL", 1)
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./saved_models/segnet_vgg_bayes/segnet_vgg_bayes_30000/model.ckpt-30000
# 101 CamVid test images are loaded

# %% [markdown]
# ## Test dataset

# %%
SegNet().visual_results("TEST", 3)
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./saved_models/segnet_vgg_bayes/segnet_vgg_bayes_30000/model.ckpt-30000
# 233 CamVid test images are loaded
