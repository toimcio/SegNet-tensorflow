# %%
import SegNet

# %%
model = SegNet.SegNet("config_rgb.json")
# Out:
# VGG parameter loaded

# %%
model.train(max_steps=15000, batch_size=5)
# Out:
# Filling queue with 300 input images before starting to train. This may take some time.
# generating image and label batch:
# Filling queue with 300 input images before starting to train. This may take some time.
# generating image and label batch:
# Running with Adam Optimizer with learning rate: 0.001
# Iteration 0: Train Loss 5.320, Train Accu  0.003
# accuracy = 0.005916
# mean IU  = 0.000254
#     class # 0 accuracy = 0.012190
#     class # 1 accuracy = 0.005108
#     class # 2 accuracy = 0.005113
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000154
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.007494
#     class # 7 accuracy = 0.011507
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.000000
#     class # 12 accuracy = 0.000000
#     class # 13 accuracy = 0.000000
#     class # 14 accuracy = 0.000000
#     class # 15 accuracy = 0.000000
# ...

# %%
model.save()
